# %%
import csv
import os
import pandas as pd

# %%
with open("beatles-diskography1.csv")  as file:
    
    
    reader=csv.reader(file)
    fil=[]
    for row in reader:
        fil.append(row)

# %%
pd.DataFrame(fil)
# Out:
#                                         0          1  \
# 0                                   Title   Released
# 1                        Please Please Me  22-Mar-63
# 2                        With the Beatles  22-Nov-63
# 3           Beatlemania! With the Beatles  25-Nov-63
# 4              Introducing... The Beatles  10-Jan-64
# 5                       Meet the Beatles!  20-Jan-64
# 6                         Twist and Shout   3-Feb-64
# 7               The Beatles' Second Album  10-Apr-64
# 8            The Beatles' Long Tall Sally  11-May-64
# 9                      A Hard Day's Night  26-Jun-64
# 10                                         10-Jul-64
# 11                          Something New  20-Jul-64
# 12                       Beatles for Sale   4-Dec-64
# 13                            Beatles '65  15-Dec-64
# 14                             Beatles VI  14-Jun-65
# 15                                  Help!   6-Aug-65
# 16                                         13-Aug-65
# ...

# %%
#df=pd.DataFrameD(row)([columns='Title','released','label','UK chart position','US chart position''BPI Certification', 'RIAA Certification'] inplace=True)

# %%
 
df="beatles-diskography1.csv"
def cscv(df):
    df1=[]

    with open(df) as file:
    
        reader=csv.reader(file)
        for row in reader:
            df1.append(row)
        return df1
obj=cscv(df)

# %%
a=pd.DataFrame(obj)
a
# Out:
#                                         0          1  \
# 0                                   Title   Released
# 1                        Please Please Me  22-Mar-63
# 2                        With the Beatles  22-Nov-63
# 3           Beatlemania! With the Beatles  25-Nov-63
# 4              Introducing... The Beatles  10-Jan-64
# 5                       Meet the Beatles!  20-Jan-64
# 6                         Twist and Shout   3-Feb-64
# 7               The Beatles' Second Album  10-Apr-64
# 8            The Beatles' Long Tall Sally  11-May-64
# 9                      A Hard Day's Night  26-Jun-64
# 10                                         10-Jul-64
# 11                          Something New  20-Jul-64
# 12                       Beatles for Sale   4-Dec-64
# 13                            Beatles '65  15-Dec-64
# 14                             Beatles VI  14-Jun-65
# 15                                  Help!   6-Aug-65
# 16                                         13-Aug-65
# ...

# %%
with open("beatles-diskography1.csv")  as file:
    
    
    reader=csv.DictReader(file)
    fil1=[]
    for row in reader:
        fil1.append(row)

# %%
pd.DataFrame(fil1)
# Out:
#                                     Title   Released  \
# 0                        Please Please Me  22-Mar-63
# 1                        With the Beatles  22-Nov-63
# 2           Beatlemania! With the Beatles  25-Nov-63
# 3              Introducing... The Beatles  10-Jan-64
# 4                       Meet the Beatles!  20-Jan-64
# 5                         Twist and Shout   3-Feb-64
# 6               The Beatles' Second Album  10-Apr-64
# 7            The Beatles' Long Tall Sally  11-May-64
# 8                      A Hard Day's Night  26-Jun-64
# 9                                          10-Jul-64
# 10                          Something New  20-Jul-64
# 11                       Beatles for Sale   4-Dec-64
# 12                            Beatles '65  15-Dec-64
# 13                             Beatles VI  14-Jun-65
# 14                                  Help!   6-Aug-65
# 15                                         13-Aug-65
# 16                            Rubber Soul   3-Dec-65
# ...
