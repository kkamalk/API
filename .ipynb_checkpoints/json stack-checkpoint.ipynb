# %%
import requests
import json
import pandas as pd

# %%
Api_Key='2pDLa5j4iIts8ie0QfcC55oGVCdMcXjV'
url='https://api.nytimes.com/svc/mostpopular/v2/viewed/7.json?api-key=2pDLa5j4iIts8ie0QfcC55oGVCdMcXjV'
response=requests.get('https://api.nytimes.com/svc/mostpopular/v2/viewed/7.json?api-key=2pDLa5j4iIts8ie0QfcC55oGVCdMcXjV').json()

# %%
for x in b['results']:
    print (x['title'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 for x in b['results']:
#       2     print (x['title'])
#
# NameError: name 'b' is not defined

# %%
Api_Key='2pDLa5j4iIts8ie0QfcC55oGVCdMcXjV'
response=requests.get('https://api.nytimes.com/svc/mostpopular/v2/viewed/7.json?api-key=2pDLa5j4iIts8ie0QfcC55oGVCdMcXjV').json()
def mdn(response):
    data=[]
    source=[]
    published_date=[]
    adx_keywords=[]
    byline=[]
    title=[]
    abstract=[]
    des_facet=[]
    per_facet=[]
    media=[]


    for i in response ['results']:
        source.append(i['source'])
        published_date.append(i['published_date'])
        adx_keywords.append(i['adx_keywords'])
        byline.append(i['byline'])
        title.append(i['title'])
        abstract.append(i['abstract'])
        des_facet.append(i['des_facet'])
        per_facet.append(i['per_facet'])
        media.append(i['media'])

        x={'source':source,'published_date':published_date,'adx_keywords':adx_keywords,'byline':byline,\
                       'title':title,'abstract':abstract,'des_facet':des_facet, 'per_facet':per_facet,\
                       'media':media}
        data.append(x)    
              

    return data
obj=mdn(response)

# %%
e=pd.DataFrame(obj)
e.head(2)
# Out:
#                                               source  \
# 0  [New York Times, New York Times, New York Time...
# 1  [New York Times, New York Times, New York Time...
#
#                                       published_date  \
# 0  [2022-08-02, 2022-08-03, 2022-07-30, 2022-08-0...
# 1  [2022-08-02, 2022-08-03, 2022-07-30, 2022-08-0...
#
#                                         adx_keywords  \
# 0  [Kidnapping and Hostages;Child Abuse and Negle...
# 1  [Kidnapping and Hostages;Child Abuse and Negle...
#
#                                               byline  \
# 0  [By McKenna Oxenden and Michael Levenson, By E...
# 1  [By McKenna Oxenden and Michael Levenson, By E...
#
#                                                title  \
# 0  [Girl, 12, Escapes Captivity, Leading Alabama ...
# 1  [Girl, 12, Escapes Captivity, Leading Alabama ...
#
#                                             abstract  \
# 0  [José Paulino Pascual-Reyes, 37, was charged w...
# ...

# %%
 def get_info():
        list = []
        api_key = "2pDLa5j4iIts8ie0QfcC55oGVCdMcXjV"
        url = 'https://api.nytimes.com/svc/mostpopular/v2/viewed/7.json?api-key=2pDLa5j4iIts8ie0QfcC55oGVCdMcXjV'
        response = requests.get(url).json()
    
        for i in response['results']:
            source =i['source']
            published_date =i['published_date']
            adx_keywords =i['adx_keywords']
            byline = i['byline']
            title = i['title']
            abstract = i['abstract']
            des_facet = i['des_facet']
            per_facet = i['per_facet']
            media = i['media']
    
            d = {'source': source, 'published_date': published_date, 'adx_keywords': adx_keywords,
                 'byline': byline, 'title': title, 'abstract': abstract, 'des_facet': des_facet,
                 'per_facet': per_facet, 'media': media}
            list.append(d)
    
    
        return list
    
    
    
data = get_info()
print(data)
# Out:
# [{'source': 'New York Times', 'published_date': '2022-08-02', 'adx_keywords': 'Kidnapping and Hostages;Child Abuse and Neglect;Murders, Attempted Murders and Homicides;Pascual-Reyes, Jose Paulino;Dadeville (Ala)', 'byline': 'By McKenna Oxenden and Michael Levenson', 'title': 'Girl, 12, Escapes Captivity, Leading Alabama Authorities to Find 2 Bodies', 'abstract': 'José Paulino Pascual-Reyes, 37, was charged with capital murder and first-degree kidnapping after the authorities said they found two decomposing bodies inside his house.', 'des_facet': ['Kidnapping and Hostages', 'Child Abuse and Neglect', 'Murders, Attempted Murders and Homicides'], 'per_facet': ['Pascual-Reyes, Jose Paulino'], 'media': [{'type': 'image', 'subtype': 'photo', 'caption': '“She’s a hero,” Sheriff Jimmy Abbett of Tallapoosa County, Ala., said of a 12-year-old girl who had managed to escape from captivity. “She’s safe and we want to keep her that way.”', 'copyright': 'WSFA', 'approved_for_syndication': 1, 'medi
# ...

# %%
p=pd.DataFrame(data)
p
# Out:
#             source published_date  \
# 0   New York Times     2022-08-02
# 1   New York Times     2022-08-03
# 2   New York Times     2022-07-30
# 3   New York Times     2022-08-03
# 4   New York Times     2022-08-04
# 5   New York Times     2022-08-02
# 6   New York Times     2022-08-01
# 7   New York Times     2022-08-01
# 8   New York Times     2022-08-04
# 9   New York Times     2022-08-02
# 10  New York Times     2022-07-31
# 11  New York Times     2022-08-04
# 12  New York Times     2022-08-01
# 13  New York Times     2022-08-04
# 14  New York Times     2022-08-01
# 15  New York Times     2022-07-31
# 16  New York Times     2022-08-01
# 17  New York Times     2022-08-02
# 18  New York Times     2022-08-03
# 19  New York Times     2022-08-03
#
#                                          adx_keywords  \
# 0   Kidnapping and Hostages;Child Abuse and Neglec...
# 1   Newtown, Conn, Shooting (2012);Suits and Litig...
# 2   Rivers;Murders, Attempted Murders and Homicide...
# ...
